# %% [markdown]
# ## Klasifikasi Text Mining menggunakan Naive Bayes

# %% [markdown]
# # load drive

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# import sys
# sys.path.append('/content/drive/My Drive/Colab Notebooks/AMS2023')

# %% [markdown]
# # install library ekphrasis

# %%
# %pip install ekphrasis
# %pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ekphrasis in c:\users\mmurt\appdata\roaming\python\python312\site-packages (0.5.4)
# Requirement already satisfied: termcolor in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from ekphrasis) (3.2.0)
# Requirement already satisfied: tqdm in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from ekphrasis) (4.67.1)
# Requirement already satisfied: colorama in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from ekphrasis) (0.4.6)
# Requirement already satisfied: ujson in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from ekphrasis) (5.11.0)
# Requirement already satisfied: matplotlib in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from ekphrasis) (3.10.7)
# Requirement already satisfied: nltk in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from ekphrasis) (3.9.2)
# Requirement already satisfied: ftfy in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from ekphrasis) (6.3.1)
# Requirement already satisfied: numpy in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from ekphrasis) (2.3.4)
# Requirement already satisfied: wcwidth in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from ftfy->ekphrasis) (0.2.14)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from matplotlib->ekphrasis) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from matplotlib->ekphrasis) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from matplotlib->ekphrasis) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from matplotlib->ekphrasis) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from matplotlib->ekphrasis) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from matplotlib->ekphrasis) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from matplotlib->ekphrasis) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from matplotlib->ekphrasis) (2.9.0.post0)
# Requirement already satisfied: click in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from nltk->ekphrasis) (8.3.0)
# Requirement already satisfied: joblib in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from nltk->ekphrasis) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from nltk->ekphrasis) (2025.11.3)
# Requirement already satisfied: six>=1.5 in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib->ekphrasis) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openpyxl in c:\users\mmurt\appdata\roaming\python\python312\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\mmurt\appdata\roaming\python\python312\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['email', 'percent', 'money', 'phone', 'user',
        'time', 'date', 'number'],
    # terms that will be annotated
    #annotate={"hashtag", "allcaps", "elongated", "repeated",'emphasis', 'censored'},
    annotate={"hashtag","allcaps","elongated","repeated",'emphasis','censored'},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated words
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)
# Out:
# C:\Users\MMurt\AppData\Roaming\Python\Python312\site-packages\ekphrasis\classes\tokenizer.py:225: FutureWarning: Possible nested set at position 2190
#   self.tok = re.compile(r"({})".format("|".join(pipeline)))
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...
# C:\Users\MMurt\AppData\Roaming\Python\Python312\site-packages\ekphrasis\classes\exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in

# %% [markdown]
# # load library

# %%
import re
import string 
import pandas as pd
from copy import deepcopy

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

# %% [markdown]
# # load dataset

# %%
df = pd.read_csv('../dataset/Dataset_Sentimen_Emosi.csv')
df.head()
# Out:
#                                                Tweet  Sentimen  Emosi
# 0  emang lemes bgt ya mulut lu, gue yg mau beli-b...      -1.0     -2
# 1  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0      1
# 2  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0     -1
# 3  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0      1
# 4            Covid belum nyampe prigen mbak hmm hoax       0.0     -2

# %% [markdown]
# karena kita hanya ingin fokus di Sentimen analysis, maka kita hanya pakai `Sentimen` sebagai target class nya **class**

# %%
df = df.drop(['Emosi'], axis=1)
df.head()
# Out:
#                                                Tweet  Sentimen
# 0  emang lemes bgt ya mulut lu, gue yg mau beli-b...      -1.0
# 1  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 2  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 3  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 4            Covid belum nyampe prigen mbak hmm hoax       0.0

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## setting fungsi

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

stemmer = StemmerFactory().create_stemmer()
stopword = StopWordRemoverFactory().create_stop_word_remover()

class TextProcessor:
    def pre_process_doc(self, text):
        text = text.lower()
        text = stopword.remove(text)
        text = stemmer.stem(text)
        return text.split()

text_processor = TextProcessor()

# %%
def bersih_data(text):
    return " ".join(text_processor.pre_process_doc(text))

def non_ascii(text):
    return text.encode('ascii', 'replace').decode('ascii')

def remove_space_alzami(text):
    return " ".join(text.split())

def remove_emoji_alzami(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

def remove_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

def remove_tab2(text):
    return re.sub(r'\s+', ' ', text)

def remove_rt(text):
    return text.replace('RT'," ")

def remove_mention(text):
    return ' '.join(re.sub(r"([@#][A-Za-z0-9]+)|(\w+://\S+)", " ", text).split())

def remove_incomplete_url(text):
    return text.replace("http://", " ").replace("https://", " ")

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def change_stripe(text):
    return text.replace('-'," ")

def lower(text):
    return text.lower()

def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") # don't remove hyphens
    pattern = r"[{}]".format(remove) # create the pattern
    return re.sub(pattern, "", text)

# %% [markdown]
# ## running preprocessing
# logika main disini

# %%
final_string = []
for text in df['Tweet'].values:
    EachReviewText = ""
    proc = bersih_data(text)
    proc = remove_rt(proc) 
    proc = lower(proc)
    proc = change_stripe(proc)
    proc = remove_tab(proc)
    proc = remove_tab2(proc)
    proc = non_ascii(proc)
    proc = remove_incomplete_url(proc)
    proc = remove_single_char(proc)
    proc = remove_punctuation(proc)
    proc = remove_space_alzami(proc)
    EachReviewText = proc
    final_string.append(EachReviewText)

# %% [markdown]
# masukkan hasil preprocessing ke kolom `step01`

# %%
df["step01"] = final_string

# %%
df.head(1)
# Out:
#                                                Tweet  Sentimen  \
# 0  emang lemes bgt ya mulut lu, gue yg mau beli-b...      -1.0
#
#                                               step01
# 0  emang lemes bgt mulut lu gue yg mau beli obat ...

# %% [markdown]
# cek jumlah dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 905 entries, 0 to 904
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Tweet     905 non-null    object
#  1   Sentimen  904 non-null    float64
#  2   step01    905 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 21.3+ KB

# %% [markdown]
# ## hapus record yang kosong

# %%
df_hapus = df[~df['step01'].str.contains(" ")]

# %%
df_new = df[~df.isin(df_hapus)].dropna()

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 903 entries, 0 to 904
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Tweet     903 non-null    object
#  1   Sentimen  903 non-null    float64
#  2   step01    903 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 28.2+ KB

# %% [markdown]
# ## normalisasi kata slang

# %%
# token
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\MMurt\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
df_new['tokens'] = df['step01'].apply(word_tokenize_wrapper)

# %%
df_new.head(10)
# Out:
#                                                Tweet  Sentimen  \
# 0  emang lemes bgt ya mulut lu, gue yg mau beli-b...      -1.0
# 1  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 2  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 3  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 4            Covid belum nyampe prigen mbak hmm hoax       0.0
# 5  Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0
# 6  Pikir2 balik byk mnde plk nk setelkn lepas covid.       0.0
# 7  Selamat pagi, hari jum'at. Jum'at keempat di k...       1.0
# 8  Hikmah di balik musibah covid-19, smg para pej...       1.0
# 9  Cegah covid-19 beserta jajaran Polsek Kuranji ...       1.0
#
#                                               step01  \
# 0  emang lemes bgt mulut lu gue yg mau beli obat ...
# 1  cegah mata rantai covid 19 mari rumah hingga h...
# 2  aku mohon yaallah moga wabah covid 19 hilang r...
# 3  pemprov papua naik status jadi tanggap darurat...
# 4                  covid nyampe prigen mbak hmm hoax
# 5  nyuruh orang pintar lu aja togog kerumun orang...
# 6   pikir2 balik byk mnde plk nk setelkn lepas covid
# 7  selamat pagi hari jum at jum at empat kala pan...
# 8  hikmah balik musibah covid 19 smg jabat perint...
# 9  cegah covid 19 serta jajar polsek ranji laku a...
#
#                                               tokens
# 0  [emang, lemes, bgt, mulut, lu, gue, yg, mau, b...
# 1  [cegah, mata, rantai, covid, 19, mari, rumah, ...
# 2  [aku, mohon, yaallah, moga, wabah, covid, 19, ...
# 3  [pemprov, papua, naik, status, jadi, tanggap, ...
# 4           [covid, nyampe, prigen, mbak, hmm, hoax]
# 5  [nyuruh, orang, pintar, lu, aja, togog, kerumu...
# 6  [pikir2, balik, byk, mnde, plk, nk, setelkn, l...
# 7  [selamat, pagi, hari, jum, at, jum, at, empat,...
# 8  [hikmah, balik, musibah, covid, 19, smg, jabat...
# 9  [cegah, covid, 19, serta, jajar, polsek, ranji...

# %%
normalized_word = pd.read_excel("../dataset/kamus perbaikan kata.xlsx")

normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]

df_new['tokens_perbaikan'] = df_new['tokens'].apply(normalized_term)
# Out:
# C:\Users\MMurt\AppData\Local\Temp\ipykernel_27308\2801414349.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] not in normalized_word_dict:
# C:\Users\MMurt\AppData\Local\Temp\ipykernel_27308\2801414349.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   normalized_word_dict[row[0]] = row[1]

# %%
df_new.head()
# Out:
#                                                Tweet  Sentimen  \
# 0  emang lemes bgt ya mulut lu, gue yg mau beli-b...      -1.0
# 1  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 2  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 3  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 4            Covid belum nyampe prigen mbak hmm hoax       0.0
#
#                                               step01  \
# 0  emang lemes bgt mulut lu gue yg mau beli obat ...
# 1  cegah mata rantai covid 19 mari rumah hingga h...
# 2  aku mohon yaallah moga wabah covid 19 hilang r...
# 3  pemprov papua naik status jadi tanggap darurat...
# 4                  covid nyampe prigen mbak hmm hoax
#
#                                               tokens  \
# 0  [emang, lemes, bgt, mulut, lu, gue, yg, mau, b...
# 1  [cegah, mata, rantai, covid, 19, mari, rumah, ...
# 2  [aku, mohon, yaallah, moga, wabah, covid, 19, ...
# 3  [pemprov, papua, naik, status, jadi, tanggap, ...
# 4           [covid, nyampe, prigen, mbak, hmm, hoax]
#
#                                     tokens_perbaikan
# 0  [memang, lemes, banget, mulut, kamu, saya, yan...
# 1  [cegah, mata, rantai, covid, 19, mari, rumah, ...
# 2  [aku, mohon, yaallah, semoga, wabah, covid, 19...
# 3  [pemprov, papua, naik, status, jadi, tanggap, ...
# 4        [covid, nyampe, prigen, mbak, aduh, bohong]

# %%
df_new.iloc[0].tokens
# Out:
# ['emang',
#  'lemes',
#  'bgt',
#  'mulut',
#  'lu',
#  'gue',
#  'yg',
#  'mau',
#  'beli',
#  'obat',
#  'aja',
#  'mikirr',
#  'drmn',
#  'beli',
#  'obat',
#  'kalo',
#  'ga',
#  'kerja']

# %%
df_new.iloc[0].tokens_perbaikan
# Out:
# ['memang',
#  'lemes',
#  'banget',
#  'mulut',
#  'kamu',
#  'saya',
#  'yang',
#  'mau',
#  'beli',
#  'obat',
#  'saja',
#  'mikirr',
#  'drmn',
#  'beli',
#  'obat',
#  'kalau',
#  'tidak',
#  'kerja']

# %% [markdown]
# ## Stopword - Menggunakan Modul NLTK

# %%
from nltk.corpus import stopwords
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\MMurt\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopword = nltk.corpus.stopwords.words('indonesian')

def remove_stopwords(text):
  text = [word for word in text if word not in stopword]
  return text

df_new['Stop_removal'] = df_new['tokens_perbaikan'].apply(lambda x: remove_stopwords(x))
df_new
# Out:
#                                                  Tweet  Sentimen  \
# 0    emang lemes bgt ya mulut lu, gue yg mau beli-b...      -1.0
# 1    Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 2    aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 3    Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 4              Covid belum nyampe prigen mbak hmm hoax       0.0
# ..                                                 ...       ...
# 900  Seluruh negara di dunia mengalami masa sulit k...       1.0
# 901  Setelah covid dan skripsi disaster selesai, ma...       1.0
# 902  Malam ini!! Projek "BENDA BOLEH BINCANG" 9 mal...       0.0
# 903                Pontang - panting di koyak covid 19      -1.0
# 904  Masalahnya sekarang isu jangkitan covid. Alaaa...      -1.0
#
#                                                 step01  \
# 0    emang lemes bgt mulut lu gue yg mau beli obat ...
# 1    cegah mata rantai covid 19 mari rumah hingga h...
# 2    aku mohon yaallah moga wabah covid 19 hilang r...
# 3    pemprov papua naik status jadi tanggap darurat...
# 4                    covid nyampe prigen mbak hmm hoax
# ..                                                 ...
# 900  seluruh negara dunia alami masa sulit covid 19...
# 901  covid skripsi disaster selesai mau bgt bljr ma...
# 902  malam ini projek benda bincang 9 malam fb satu...
# 903                     pontang panting koyak covid 19
# 904  masalah sekarang isu jangkit covid alaaaa bosa...
#
#                                                 tokens  \
# 0    [emang, lemes, bgt, mulut, lu, gue, yg, mau, b...
# 1    [cegah, mata, rantai, covid, 19, mari, rumah, ...
# 2    [aku, mohon, yaallah, moga, wabah, covid, 19, ...
# 3    [pemprov, papua, naik, status, jadi, tanggap, ...
# 4             [covid, nyampe, prigen, mbak, hmm, hoax]
# ..                                                 ...
# 900  [seluruh, negara, dunia, alami, masa, sulit, c...
# 901  [covid, skripsi, disaster, selesai, mau, bgt, ...
# 902  [malam, ini, projek, benda, bincang, 9, malam,...
# 903               [pontang, panting, koyak, covid, 19]
# 904  [masalah, sekarang, isu, jangkit, covid, alaaa...
#
#                                       tokens_perbaikan  \
# 0    [memang, lemes, banget, mulut, kamu, saya, yan...
# 1    [cegah, mata, rantai, covid, 19, mari, rumah, ...
# 2    [aku, mohon, yaallah, semoga, wabah, covid, 19...
# 3    [pemprov, papua, naik, status, jadi, tanggap, ...
# 4          [covid, nyampe, prigen, mbak, aduh, bohong]
# ..                                                 ...
# 900  [seluruh, negara, dunia, alami, masa, sulit, c...
# 901  [covid, skripsi, disaster, selesai, mau, bange...
# 902  [malam, ini, proyek, benda, bincang, 9, malam,...
# 903               [pontang, panting, koyak, covid, 19]
# 904  [masalah, sekarang, isu, jangkit, covid, alaaa...
#
#                                           Stop_removal
# 0    [lemes, banget, mulut, beli, obat, mikirr, drm...
# 1    [cegah, mata, rantai, covid, 19, mari, rumah, ...
# 2    [mohon, yaallah, semoga, wabah, covid, 19, hil...
# 3    [pemprov, papua, status, tanggap, darurat, cov...
# 4          [covid, nyampe, prigen, mbak, aduh, bohong]
# ..                                                 ...
# 900  [negara, dunia, alami, sulit, covid, 19, rakya...
# 901  [covid, skripsi, disaster, selesai, banget, be...
# 902  [malam, proyek, benda, bincang, 9, malam, fb, ...
# 903               [pontang, panting, koyak, covid, 19]
# 904  [isu, jangkit, covid, alaaaa, bosan, laaa, laa...
#
# [903 rows x 6 columns]

# %%
df_new.iloc[0].tokens_perbaikan
# Out:
# ['memang',
#  'lemes',
#  'banget',
#  'mulut',
#  'kamu',
#  'saya',
#  'yang',
#  'mau',
#  'beli',
#  'obat',
#  'saja',
#  'mikirr',
#  'drmn',
#  'beli',
#  'obat',
#  'kalau',
#  'tidak',
#  'kerja']

# %%
df_new.iloc[0].Stop_removal
# Out:
# ['lemes',
#  'banget',
#  'mulut',
#  'beli',
#  'obat',
#  'mikirr',
#  'drmn',
#  'beli',
#  'obat',
#  'kerja']

# %%
i=0
final_string_tokens = []
for text in df_new['Stop_removal'].values:
    EachReviewText = ""
    EachReviewText = ' '.join(text)
    final_string_tokens.append(EachReviewText)

# %%
df_new["step02"] = final_string_tokens

# %%
df_new.head()
# Out:
#                                                Tweet  Sentimen  \
# 0  emang lemes bgt ya mulut lu, gue yg mau beli-b...      -1.0
# 1  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 2  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 3  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 4            Covid belum nyampe prigen mbak hmm hoax       0.0
#
#                                               step01  \
# 0  emang lemes bgt mulut lu gue yg mau beli obat ...
# 1  cegah mata rantai covid 19 mari rumah hingga h...
# 2  aku mohon yaallah moga wabah covid 19 hilang r...
# 3  pemprov papua naik status jadi tanggap darurat...
# 4                  covid nyampe prigen mbak hmm hoax
#
#                                               tokens  \
# 0  [emang, lemes, bgt, mulut, lu, gue, yg, mau, b...
# 1  [cegah, mata, rantai, covid, 19, mari, rumah, ...
# 2  [aku, mohon, yaallah, moga, wabah, covid, 19, ...
# 3  [pemprov, papua, naik, status, jadi, tanggap, ...
# 4           [covid, nyampe, prigen, mbak, hmm, hoax]
#
#                                     tokens_perbaikan  \
# 0  [memang, lemes, banget, mulut, kamu, saya, yan...
# 1  [cegah, mata, rantai, covid, 19, mari, rumah, ...
# 2  [aku, mohon, yaallah, semoga, wabah, covid, 19...
# 3  [pemprov, papua, naik, status, jadi, tanggap, ...
# 4        [covid, nyampe, prigen, mbak, aduh, bohong]
#
#                                         Stop_removal  \
# 0  [lemes, banget, mulut, beli, obat, mikirr, drm...
# 1  [cegah, mata, rantai, covid, 19, mari, rumah, ...
# 2  [mohon, yaallah, semoga, wabah, covid, 19, hil...
# 3  [pemprov, papua, status, tanggap, darurat, cov...
# 4        [covid, nyampe, prigen, mbak, aduh, bohong]
#
#                                               step02
# 0  lemes banget mulut beli obat mikirr drmn beli ...
# 1       cegah mata rantai covid 19 mari rumah minggu
# 2  mohon yaallah semoga wabah covid 19 hilang ram...
# 3  pemprov papua status tanggap darurat covid 19 opm
# 4               covid nyampe prigen mbak aduh bohong

# %% [markdown]
# ## Stemming - Menggunakan Sastrawi

# %%
# !pip install sastrawi

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
final_string = []
s = ""
for sentence in df_new["step02"].values:
    filteredSentence = []
    EachReviewText = ""
    s = (stemmer.stem(sentence))
    filteredSentence.append(s)
    
    EachReviewText = ' '.join(filteredSentence)
    final_string.append(EachReviewText)

# %%
df_new["ProcessedText"] = final_string

# %%
df_new.head(10)
# Out:
#                                                Tweet  Sentimen  \
# 0  emang lemes bgt ya mulut lu, gue yg mau beli-b...      -1.0
# 1  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 2  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 3  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 4            Covid belum nyampe prigen mbak hmm hoax       0.0
# 5  Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0
# 6  Pikir2 balik byk mnde plk nk setelkn lepas covid.       0.0
# 7  Selamat pagi, hari jum'at. Jum'at keempat di k...       1.0
# 8  Hikmah di balik musibah covid-19, smg para pej...       1.0
# 9  Cegah covid-19 beserta jajaran Polsek Kuranji ...       1.0
#
#                                               step01  \
# 0  emang lemes bgt mulut lu gue yg mau beli obat ...
# 1  cegah mata rantai covid 19 mari rumah hingga h...
# 2  aku mohon yaallah moga wabah covid 19 hilang r...
# 3  pemprov papua naik status jadi tanggap darurat...
# 4                  covid nyampe prigen mbak hmm hoax
# 5  nyuruh orang pintar lu aja togog kerumun orang...
# 6   pikir2 balik byk mnde plk nk setelkn lepas covid
# 7  selamat pagi hari jum at jum at empat kala pan...
# 8  hikmah balik musibah covid 19 smg jabat perint...
# 9  cegah covid 19 serta jajar polsek ranji laku a...
#
#                                               tokens  \
# 0  [emang, lemes, bgt, mulut, lu, gue, yg, mau, b...
# 1  [cegah, mata, rantai, covid, 19, mari, rumah, ...
# 2  [aku, mohon, yaallah, moga, wabah, covid, 19, ...
# 3  [pemprov, papua, naik, status, jadi, tanggap, ...
# 4           [covid, nyampe, prigen, mbak, hmm, hoax]
# 5  [nyuruh, orang, pintar, lu, aja, togog, kerumu...
# 6  [pikir2, balik, byk, mnde, plk, nk, setelkn, l...
# 7  [selamat, pagi, hari, jum, at, jum, at, empat,...
# 8  [hikmah, balik, musibah, covid, 19, smg, jabat...
# 9  [cegah, covid, 19, serta, jajar, polsek, ranji...
#
#                                     tokens_perbaikan  \
# 0  [memang, lemes, banget, mulut, kamu, saya, yan...
# 1  [cegah, mata, rantai, covid, 19, mari, rumah, ...
# 2  [aku, mohon, yaallah, semoga, wabah, covid, 19...
# 3  [pemprov, papua, naik, status, jadi, tanggap, ...
# 4        [covid, nyampe, prigen, mbak, aduh, bohong]
# 5  [nyuruh, orang, pintar, kamu, saja, togog, ker...
# 6  [pikir2, balik, banyak, mnde, plk, nk, setelkn...
# 7  [selamat, pagi, hari, jum, at, jum, at, empat,...
# 8  [hikmah, balik, musibah, covid, 19, semoga, ja...
# 9  [cegah, covid, 19, serta, jajar, polsek, ranji...
#
#                                         Stop_removal  \
# 0  [lemes, banget, mulut, beli, obat, mikirr, drm...
# 1  [cegah, mata, rantai, covid, 19, mari, rumah, ...
# 2  [mohon, yaallah, semoga, wabah, covid, 19, hil...
# 3  [pemprov, papua, status, tanggap, darurat, cov...
# 4        [covid, nyampe, prigen, mbak, aduh, bohong]
# 5  [nyuruh, orang, pintar, togog, kerumun, orang,...
# 6     [pikir2, mnde, plk, nk, setelkn, lepas, covid]
# 7  [selamat, pagi, jum, at, jum, at, pandemi, cov...
# 8  [hikmah, musibah, covid, 19, semoga, jabat, pe...
# 9  [cegah, covid, 19, jajar, polsek, ranji, laku,...
#
#                                               step02  \
# 0  lemes banget mulut beli obat mikirr drmn beli ...
# 1       cegah mata rantai covid 19 mari rumah minggu
# 2  mohon yaallah semoga wabah covid 19 hilang ram...
# 3  pemprov papua status tanggap darurat covid 19 opm
# 4               covid nyampe prigen mbak aduh bohong
# 5  nyuruh orang pintar togog kerumun orang nulari...
# 6             pikir2 mnde plk nk setelkn lepas covid
# 7  selamat pagi jum at jum at pandemi covid 19 se...
# 8  hikmah musibah covid 19 semoga jabat perintah ...
# 9  cegah covid 19 jajar polsek ranji laku aksi pe...
#
#                                        ProcessedText
# 0  lemes banget mulut beli obat mikirr drmn beli ...
# 1       cegah mata rantai covid 19 mari rumah minggu
# 2  mohon yaallah moga wabah covid 19 hilang ramadhan
# 3  pemprov papua status tanggap darurat covid 19 opm
# 4               covid nyampe prigen mbak aduh bohong
# 5  nyuruh orang pintar togog kerumun orang nulari...
# 6             pikir2 mnde plk nk setelkn lepas covid
# 7  selamat pagi jum at jum at pandemi covid 19 mo...
# 8  hikmah musibah covid 19 moga jabat perintah sa...
# 9  cegah covid 19 jajar polsek ranji laku aksi pe...

# %% [markdown]
# ## simpan hasil preprocessing

# %%
df_new.to_csv('clean_dataset_part01.csv',sep=";")

# %% [markdown]
# # Penataan Data

# %% [markdown]
# ## pembagian fitur dan label

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('clean_dataset_part01.csv',sep=";")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 903 entries, 0 to 902
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        903 non-null    int64
#  1   Tweet             903 non-null    object
#  2   Sentimen          903 non-null    float64
#  3   step01            903 non-null    object
#  4   tokens            903 non-null    object
#  5   tokens_perbaikan  903 non-null    object
#  6   Stop_removal      903 non-null    object
#  7   step02            903 non-null    object
#  8   ProcessedText     903 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 63.6+ KB

# %%
dataset_feature = dataset['ProcessedText'].astype(str)

# %%
dataset_feature.head(10)
# Out:
# 0    lemes banget mulut beli obat mikirr drmn beli ...
# 1         cegah mata rantai covid 19 mari rumah minggu
# 2    mohon yaallah moga wabah covid 19 hilang ramadhan
# 3    pemprov papua status tanggap darurat covid 19 opm
# 4                 covid nyampe prigen mbak aduh bohong
# 5    nyuruh orang pintar togog kerumun orang nulari...
# 6               pikir2 mnde plk nk setelkn lepas covid
# 7    selamat pagi jum at jum at pandemi covid 19 mo...
# 8    hikmah musibah covid 19 moga jabat perintah sa...
# 9    cegah covid 19 jajar polsek ranji laku aksi pe...
# Name: ProcessedText, dtype: object

# %%
dataset_label = dataset['Sentimen']

# %%
dataset_label.head(10)
# Out:
# 0   -1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    0.0
# 5   -1.0
# 6    0.0
# 7    1.0
# 8    1.0
# 9    1.0
# Name: Sentimen, dtype: float64

# %% [markdown]
# ## distribusi label

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Visualizing the target variable
plt.figure(figsize=(12,8))
sns.distplot(dataset_label, label=f'target, skew: {dataset_label.skew():.2f}')
plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\MMurt\AppData\Local\Temp\ipykernel_20872\1470841120.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset_label, label=f'target, skew: {dataset_label.skew():.2f}')

# %%
dataset_label.value_counts()
# Out:
# Sentimen
#  1.0    441
#  0.0    266
# -1.0    196
# Name: count, dtype: int64

# %% [markdown]
# # Ekstraksi Fitur dan Machine Learning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.model_selection import train_test_split

# %%
train_x, test_x, train_label, test_label = train_test_split(dataset_feature, dataset_label, test_size = 0.3, random_state=42)

# %%
test_x
# Out:
# 70     tips ilmuwan tingkat kebal tubuh lawan covid 1...
# 457    cegah covid 19 jajar polsek ranji laku aksi pe...
# 218    warga kabupaten lampung utara nyata positif pa...
# 250    mimpi malam psbb tahan batal covid data tekan ...
# 39     yukkk putus mata rantai semangat covid 19 indo...
#                              ...
# 864              orang bahaya covid 19 lurus belok pergi
# 638    halo gerak lawan covid 19 ayo juang informasi ...
# 352    personil polsek karanglewas laksana patroli ma...
# 465    amal langkah cegah tular covid 19 amal hidup s...
# 640           wakakakkaka puter cahaya tolong time covid
# Name: ProcessedText, Length: 271, dtype: object

# %% [markdown]
# ## load TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
Tfidf_Vectorizer = TfidfVectorizer()

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
from sklearn.pipeline import Pipeline
classifier_nb = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('model', MultinomialNB()),
])

# %%
parameters_nb = {
    'tfidf__ngram_range': [(1, 1), (1, 2), (1, 3), (1, 4)],
    'model__alpha': (0.0001, 0.001, 0.1, 1, 10, 100)
}

# %%
classifier_nb = GridSearchCV(classifier_nb, parameters_nb, cv = 3, n_jobs=-1)

# %%
classifier_nb.fit(train_x, train_label.ravel())
# Out:
# C:\Users\MMurt\AppData\Local\Temp\ipykernel_20872\4039834798.py:1: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   classifier_nb.fit(train_x, train_label.ravel())
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                        ('model', MultinomialNB())]),
#              n_jobs=-1,
#              param_grid={'model__alpha': (0.0001, 0.001, 0.1, 1, 10, 100),
#                          'tfidf__ngram_range': [(1, 1), (1, 2), (1, 3),
#                                                 (1, 4)]})

# %%
y_pred_nb_train = classifier_nb.predict(train_x)
accuracy_nb_train = accuracy_score(train_label, y_pred_nb_train)
print("Accuracy Training set: ", accuracy_nb_train)

y_pred_nb_test = classifier_nb.predict(test_x)
accuracy_nb_test = accuracy_score(test_label, y_pred_nb_test)
print("Accuracy Test set: ", accuracy_nb_test)
# Out:
# Accuracy Training set:  0.9762658227848101
# Accuracy Test set:  0.6014760147601476

# %%
recall_nb_train = recall_score(train_label, y_pred_nb_train, average='weighted')
print("Recall Training set: ", recall_nb_train)

recall_nb_test = recall_score(test_label, y_pred_nb_test, average='weighted')
print("Recall Test set: ", recall_nb_test)
# Out:
# Recall Training set:  0.9762658227848101
# Recall Test set:  0.6014760147601476

# %%
precision_nb_train = precision_score(train_label, y_pred_nb_train, average='weighted')
print("Precision Training set: ", precision_nb_train)

precision_nb_test = precision_score(test_label, y_pred_nb_test, average='weighted')
print("Precision Test set: ", precision_nb_test)
# Out:
# Precision Training set:  0.9763109028546875
# Precision Test set:  0.5793507737470169

# %%
f1_nb_train = f1_score(train_label, y_pred_nb_train, average='weighted')
print("F1 Training set: ", f1_nb_train)

f1_nb_test = f1_score(test_label, y_pred_nb_test, average='weighted')
print("F1 Test set: ", f1_nb_test)
# Out:
# F1 Training set:  0.9762755093871983
# F1 Test set:  0.5839774925917921

# %%
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(test_label, y_pred_nb_test), annot=True, cmap = 'viridis', fmt='.0f')
plt.xlabel("Predicted values", fontdict = {'size':14}, labelpad = 10)
plt.ylabel("Actual values"   , fontdict = {'size':14}, labelpad = 10)
plt.title ("Confusion Matrix", fontdict = {'size':18}, pad = 20)
plt.show()

# %%
classifier_nb.best_estimator_
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('model', MultinomialNB(alpha=0.1))])

# %%
for param_name in sorted(parameters_nb.keys()):
    print("%s: %r" % (param_name, classifier_nb.best_params_[param_name]))
# Out:
# model__alpha: 0.1
# tfidf__ngram_range: (1, 1)

# %% [markdown]
# # Visualisasi

# %%
models = [        
          ('Naive Bayes Multinomial', accuracy_nb_train, accuracy_nb_test),
         ]

# %%
predict = pd.DataFrame(data = models, columns=['Model', 'Training Accuracy', 'Test Accuracy'])
predict
# Out:
#                      Model  Training Accuracy  Test Accuracy
# 0  Naive Bayes Multinomial           0.976266       0.601476

# %%
models_comparison = [                        
                        ('Naive Bayes Multinomial', accuracy_nb_test, recall_nb_test, precision_nb_test, f1_nb_test)                      
                    ]

# %%
comparison = pd.DataFrame(data = models_comparison, columns=['Model', 'Accuracy', 'Recall', 'Precision', 'F1 Weighted'])
comparison
# Out:
#                      Model  Accuracy    Recall  Precision  F1 Weighted
# 0  Naive Bayes Multinomial  0.601476  0.601476   0.579351     0.583977

# %%
import numpy as np

f, axes = plt.subplots(2,1, figsize=(14,10))

predict.sort_values(by=['Training Accuracy'], ascending=False, inplace=True)

sns.barplot(x='Training Accuracy', y='Model', data = predict, palette='Blues_d', ax = axes[0])
#axes[0].set(xlabel='Region', ylabel='Charges')
axes[0].set_xlabel('Training Accuracy', size=16)
axes[0].set_ylabel('Model')
axes[0].set_xlim(0,1.0)
axes[0].set_xticks(np.arange(0, 1.1, 0.1))

predict.sort_values(by=['Test Accuracy'], ascending=False, inplace=True)

sns.barplot(x='Test Accuracy', y='Model', data = predict, palette='Greens_d', ax = axes[1])
#axes[0].set(xlabel='Region', ylabel='Charges')
axes[1].set_xlabel('Test Accuracy', size=16)
axes[1].set_ylabel('Model')
axes[1].set_xlim(0,1.0)
axes[1].set_xticks(np.arange(0, 1.1, 0.1))

plt.show()
# Out:
# C:\Users\MMurt\AppData\Local\Temp\ipykernel_20872\2750282873.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Training Accuracy', y='Model', data = predict, palette='Blues_d', ax = axes[0])
# C:\Users\MMurt\AppData\Local\Temp\ipykernel_20872\2750282873.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Test Accuracy', y='Model', data = predict, palette='Greens_d', ax = axes[1])

# %% [markdown]
# # simpan kedalam joblib

# %%
import joblib

# %%
# save the model to disk
joblib.dump(classifier_nb.best_estimator_, 'classifier_nb.best_estimator_.sav', compress=1)
# Out:
# ['classifier_nb.best_estimator_.sav']
